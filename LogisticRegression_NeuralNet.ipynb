# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

y_test = np.array(y_test)
y_train = np.array(y_train)

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/100
# 576/576 [==============================] - 1s 1ms/sample - loss: 0.7422 - accuracy: 0.5938
# Epoch 2/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.6967 - accuracy: 0.6059
# Epoch 3/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.6599 - accuracy: 0.6215
# Epoch 4/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.6302 - accuracy: 0.6510
# Epoch 5/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.6059 - accuracy: 0.6806
# Epoch 6/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5841 - accuracy: 0.7170
# Epoch 7/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.5660 - accuracy: 0.7309
# Epoch 8/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5507 - accuracy: 0.7413
# Epoch 9/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5372 - accuracy: 0.7517
# Epoch 10/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.5257 - accuracy: 0.7552
# Epoch 11/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.5152 - accuracy: 0.7587
# Epoch 12/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.5060 - accuracy: 0.7639
# Epoch 13/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4980 - accuracy: 0.7795
# Epoch 14/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4915 - accuracy: 0.7865
# Epoch 15/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4853 - accuracy: 0.7882
# Epoch 16/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4800 - accuracy: 0.7865
# Epoch 17/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4750 - accuracy: 0.7899
# Epoch 18/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4710 - accuracy: 0.7882
# Epoch 19/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4675 - accuracy: 0.7934
# Epoch 20/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4641 - accuracy: 0.7917
# Epoch 21/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4612 - accuracy: 0.7882
# Epoch 22/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4585 - accuracy: 0.7934
# Epoch 23/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4563 - accuracy: 0.7917
# Epoch 24/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4545 - accuracy: 0.7951
# Epoch 25/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4526 - accuracy: 0.7969
# Epoch 26/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4511 - accuracy: 0.7969
# Epoch 27/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4495 - accuracy: 0.7969
# Epoch 28/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4484 - accuracy: 0.7969
# Epoch 29/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4469 - accuracy: 0.7951
# Epoch 30/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4458 - accuracy: 0.7917
# Epoch 31/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4448 - accuracy: 0.7917
# Epoch 32/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4441 - accuracy: 0.7934
# Epoch 33/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4430 - accuracy: 0.7934
# Epoch 34/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4422 - accuracy: 0.7899
# Epoch 35/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4418 - accuracy: 0.7934
# Epoch 36/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4407 - accuracy: 0.7951
# Epoch 37/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4400 - accuracy: 0.7934
# Epoch 38/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4395 - accuracy: 0.7934
# Epoch 39/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4391 - accuracy: 0.7899
# Epoch 40/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4385 - accuracy: 0.7951
# Epoch 41/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4377 - accuracy: 0.7951
# Epoch 42/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4369 - accuracy: 0.7969
# Epoch 43/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4365 - accuracy: 0.7917
# Epoch 44/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4362 - accuracy: 0.7917
# Epoch 45/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4356 - accuracy: 0.7986
# Epoch 46/100
# 576/576 [==============================] - 0s 74us/sample - loss: 0.4349 - accuracy: 0.7951
# Epoch 47/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4345 - accuracy: 0.7969
# Epoch 48/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4342 - accuracy: 0.7951
# Epoch 49/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4335 - accuracy: 0.7951
# Epoch 50/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4329 - accuracy: 0.7951
# Epoch 51/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4326 - accuracy: 0.7969
# Epoch 52/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4323 - accuracy: 0.7951
# Epoch 53/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4318 - accuracy: 0.7969
# Epoch 54/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4312 - accuracy: 0.7951
# Epoch 55/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4312 - accuracy: 0.7951
# Epoch 56/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4302 - accuracy: 0.7951
# Epoch 57/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4304 - accuracy: 0.7969
# Epoch 58/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4294 - accuracy: 0.7969
# Epoch 59/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4293 - accuracy: 0.7969
# Epoch 60/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4289 - accuracy: 0.7969
# Epoch 61/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4286 - accuracy: 0.7969
# Epoch 62/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4280 - accuracy: 0.7969
# Epoch 63/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4276 - accuracy: 0.7969
# Epoch 64/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4271 - accuracy: 0.7969
# Epoch 65/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4265 - accuracy: 0.7969
# Epoch 66/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4261 - accuracy: 0.7986
# Epoch 67/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4260 - accuracy: 0.8003
# Epoch 68/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4253 - accuracy: 0.8003
# Epoch 69/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4251 - accuracy: 0.8003
# Epoch 70/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4243 - accuracy: 0.8021
# Epoch 71/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4242 - accuracy: 0.8021
# Epoch 72/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4236 - accuracy: 0.8003
# Epoch 73/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4234 - accuracy: 0.7969
# Epoch 74/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4229 - accuracy: 0.8003
# Epoch 75/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4222 - accuracy: 0.8003
# Epoch 76/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4220 - accuracy: 0.8021
# Epoch 77/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4213 - accuracy: 0.8003
# Epoch 78/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4207 - accuracy: 0.8003
# Epoch 79/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4205 - accuracy: 0.7986
# Epoch 80/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4198 - accuracy: 0.7986
# Epoch 81/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4195 - accuracy: 0.7969
# Epoch 82/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4194 - accuracy: 0.8003
# Epoch 83/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4188 - accuracy: 0.8003
# Epoch 84/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4188 - accuracy: 0.8021
# Epoch 85/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4180 - accuracy: 0.8003
# Epoch 86/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4176 - accuracy: 0.8038
# Epoch 87/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4175 - accuracy: 0.8021
# Epoch 88/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4168 - accuracy: 0.8021
# Epoch 89/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4166 - accuracy: 0.8021
# Epoch 90/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4163 - accuracy: 0.8038
# Epoch 91/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4161 - accuracy: 0.8021
# Epoch 92/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4159 - accuracy: 0.8038
# Epoch 93/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4152 - accuracy: 0.8021
# Epoch 94/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4149 - accuracy: 0.8021
# Epoch 95/100
# 576/576 [==============================] - 0s 60us/sample - loss: 0.4146 - accuracy: 0.8021
# Epoch 96/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4144 - accuracy: 0.8038
# Epoch 97/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4142 - accuracy: 0.8021
# Epoch 98/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4136 - accuracy: 0.8021
# Epoch 99/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4132 - accuracy: 0.8038
# Epoch 100/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4135 - accuracy: 0.8038
# 192/1 - 0s - loss: 0.5208 - accuracy: 0.7240
# Loss: 0.5001315921545029, Accuracy: 0.7239583134651184
